# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://www.indiabusinesstoday.in/category/plant-and-machinery-1-834'
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
# Out:
# c:\users\user\miniconda2\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file c:\users\user\miniconda2\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %% [markdown]
# ### Company details in first page

# %%
table = soup.find_all('div', {'class':'col-sm-12'}).find()

# %%
for i in range(7,len(table)):
    if table[i].find('div',{'class':'row col-sm-12'}):
        print "-------"
        print i,"\n"
        print table[i].prettify()
        print "\n"
# Out:
# -------
# 10
#
# <div class="col-sm-12">
#  <div class="row">
#   <!-- content row -->
#   <div class="col-sm-2">
#    <img alt="welding flux manufacturer from China -- Yulin Welding Material" class="img-responsive thumbnail view-img" src="http://www.indiabusinesstoday.in/assets/images/logo/thumbs/thumb__20151208092250_副本.jpg" title="welding flux manufacturer from China -- Yulin Welding Material"/>
#   </div>
#   <div class="col-sm-3">
#    <div class="row col-sm-12">
#     <a href="http://www.indiabusinesstoday.in/detail/welding-flux-manufacturer-from-china-yulin-welding-material-delhi-549947">
#      welding flux manufacturer from China -- Yulin Welding Material
#     </a>
#    </div>
#    <div class="row col-sm-12">
#     <button class="query btn btn-sm btn-primary" data-target="#query-modal" data-toggle="modal" id="549947" onclick="viewPage(549947);" type="button">
#      Send Query
#     </button>
#    </div>
#    <!-- end of ask query -->
#   </div>
#   <div class="col-sm-3">
#    <strong>
#     Delhi
#    </strong>
#    <br/>
#   </div>
#   <div class="col-sm-4">
#    Wanghe Village, Gongyi, Henan, China
#    <br/>
#    Delhi, Delhi 451200
#    <br/>
#    India
#    <br/>
#    <strong>
#     Phone No:
#    </strong>
#    +8618530036598, +8637169596866
#   </div>
#  </div>
#  <!-- end of content row -->
#  <div class="row top2">
#   <!-- tag and business query -->
#   <div class="col-sm-2">
#   </div>
#   <div class="col-sm-10">
#    <a href="http://www.indiabusinesstoday.in/search?q=sub+arc+flux&amp;l=Delhi&amp;c=834&amp;tl=1&amp;t=4383">
#     sub arc flux
#    </a>
#    ,
#    <a href="http://www.indiabusinesstoday.in/search?q=submerged+arc+welding+flux&amp;l=Delhi&amp;c=834&amp;tl=1&amp;t=4382">
#     submerged arc welding flux
#    </a>
#    ,
#    <a href="http://www.indiabusinesstoday.in/search?q=welding+flux&amp;l=Delhi&amp;c=834&amp;tl=1&amp;t=4381">
#     welding flux
#    </a>
#    <a href="http://www.indiabusinesstoday.in/detail/welding-flux-manufacturer-from-china-yulin-welding-material-delhi-549947">
#     more...
#    </a>
#   </div>
#  </div>
#  <!-- end of tag and business query -->
#  <div class="row">
#   <!-- description -->
#   <div class="col-sm-12">
#    <div class="wrap">
#     <a class="readmorebtn" onclick="$(this).text($(this).text() == '+more' ? '-less' : '+more').next('#listing_description_549947').slideToggle('fast');">
#      +more
#     </a>
#     <div id="listing_description_549947" style="display:none">
#      <p>
#       <span>
#        Gongyi Yulin Welding Material Co. Ltd is engaged in the research &amp; development &amp; production of
#        <a href="Gongyi Yulin Welding Material Co. Ltd is engaged in the research &amp; development &amp; production of submerged arc welding fluxes (SAW flux). Our competitive products are agglomerated flux, fused flux, welding wires. Taking a leading position in regards to mild steel &amp; low-alloy steel welding, heat resistant stainless steel welding, roll rebuilding &amp; hardfacing, we are providing solutions for applications like pipeline, heavy machinery, pressure vessel, LPG tanks, vehicle, shipbuilding, bridge building, steel construction.">
#         submerged arc welding fluxes
#        </a>
#        (SAW flux). Our competitive products are agglomerated flux, fused flux, welding wires. Taking a leading position in regards to mild steel &amp; low-alloy steel welding, heat resistant stainless steel welding, roll rebuilding &amp; hardfacing, we are providing solutions for applications like pipeline, heavy machinery, pressure vessel, LPG tanks, vehicle, shipbuilding, bridge building, steel construction.
#       </span>
#      </p>
#     </div>
#    </div>
#    <!-- end of wrap -->
#   </div>
#   <!-- end of col-sm-12 -->
#  </div>
#  <!-- end of description -->
#  <!-- end of advertisement -->
# </div>
#
#
#
# -------
# 14
#
# <div class="col-sm-12">
#  <div class="row">
#   <!-- content row -->
#   <div class="col-sm-2">
#    <img alt="Shree Kamdhenu Electronics Pvt Ltd" class="img-responsive thumbnail view-img" src="http://www.indiabusinesstoday.in/assets/images/logo/thumbs/thumb__kd.JPG" title="Shree Kamdhenu Electronics Pvt Ltd"/>
#   </div>
#   <div class="col-sm-3">
#    <div class="row col-sm-12">
#     <a href="http://www.indiabusinesstoday.in/detail/shree-kamdhenu-electronics-pvt-ltd-1-549461">
#      Shree Kamdhenu Electronics Pvt Ltd
#     </a>
#    </div>
#    <div class="row col-sm-12">
#     <button class="query btn btn-sm btn-primary" data-target="#query-modal" data-toggle="modal" id="549461" onclick="viewPage(549461);" type="button">
#      Send Query
#     </button>
#    </div>
#    <!-- end of ask query -->
#   </div>
#   <div class="col-sm-3">
#    <strong>
#     Anand
#    </strong>
#    <br/>
#   </div>
#   <div class="col-sm-4">
#    102, Shivam Complex, Nana Bazar,
# VidyaNagar
#    <br/>
#    Anand, Gujarat 388120
#    <br/>
#    India
#    <br/>
#    <strong>
#     Phone No:
#    </strong>
#    02692-235390
#   </div>
#  </div>
#  <!-- end of content row -->
#  <div class="row top2">
#   <!-- tag and business query -->
#   <div class="col-sm-2">
#   </div>
#   <div class="col-sm-10">
#    <a href="http://www.indiabusinesstoday.in/search?q=akashganga-+electronics+weighing+scales&amp;l=Anand&amp;c=834&amp;tl=1&amp;t=3778">
#     akashganga- electronics weighing scales
#    </a>
#    ,
#    <a href="http://www.indiabusinesstoday.in/search?q=automatic+milk+collection+systems+-+computerised&amp;l=Anand&amp;c=834&amp;tl=1&amp;t=3775">
#     automatic milk collection systems - computerised
#    </a>
#    ,
#    <a href="http://www.indiabusinesstoday.in/search?q=automatic+milk+collection+systems+-+data+processor&amp;l=Anand&amp;c=834&amp;tl=1&amp;t=3776">
#     automatic milk collection systems - data processor
#    </a>
#    ,
#    <a href="http://www.indiabusinesstoday.in/search?q=milk+analyzer+(fat-snf+testing+machine)&amp;l=Anand&amp;c=834&amp;tl=1&amp;t=3777">
#     milk analyzer (fat-snf testing machine)
#    </a>
#    <a href="http://www.indiabusinesstoday.in/detail/shree-kamdhenu-electronics-pvt-ltd-1-549461">
#     more...
#    </a>
#   </div>
#  </div>
#  <!-- end of tag and business query -->
#  <div class="row">
#   <!-- description -->
#   <div class="col-sm-12">
#    <div class="wrap">
#     <a class="readmorebtn" onclick="$(this).text($(this).text() == '+more' ? '-less' : '+more').next('#listing_description_549461').slideToggle('fast');">
#      +more
#     </a>
#     <div id="listing_description_549461" style="display:none">
#      <p>
#       <a class="cdlink_center" href="http://www.akashganga.in/amcscomputer.htm">
#        Automatic Milk Collection Systems - Computerised
#       </a>
#       ,
#       <a class="cdlink_center" href="http://www.akashganga.in/amcsmicro.htm">
#        Automatic Milk Collection Systems - Data Processor
#       </a>
#       ,
#       <a class="cdlink_center" href="http://www.akashganga.in/fatsnf.htm">
#        Milk Analyzer (FAT-SNF Testing Machine)
#       </a>
#       ,
#       <a class="cdlink_center" href="http://www.akashganga.in/WeighingScales.htm">
#        Akashganga- Electronics Weighing Scales
#       </a>
#      </p>
#     </div>
#    </div>
#    <!-- end of wrap -->
#   </div>
#   <!-- end of col-sm-12 -->
#  </div>
#  <!-- end of description -->
#  <!-- end of advertisement -->
# </div>
#
#
#
# -------
# 18
#
# <div class="col-sm-12">
#  <div class="row">
#   <!-- content row -->
#   <div class="col-sm-2">
#    <img alt="AGROCON INTERNATIONAL" class="img-responsive thumbnail view-img" src="http://www.indiabusinesstoday.in/assets/images/logo/no-logo.png" title="AGROCON INTERNATIONAL"/>
#    <div class="row">
#     <div class="col-sm-12">
#      <div class="stars" id="listing_rating">
#       <div class="controls">
#        <input class="rating" data-disabled="true" data-show-caption="false" data-show-clear="false" data-size="xs" id="input-ratings" max="5" min="0" step="0.5" type="number" value="3.6"/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="col-sm-3">
#    <div class="row col-sm-12">
#     <a href="http://www.indiabusinesstoday.in/detail/agrocon-international-1031">
#      AGROCON INTERNATIONAL
#     </a>
#    </div>
#    <div class="row col-sm-12">
#     <button class="query btn btn-sm btn-primary" data-target="#query-modal" data-toggle="modal" id="1031" onclick="viewPage(1031);" type="button">
#      Send Query
#     </button>
#    </div>
#    <!-- end of ask query -->
#   </div>
#   <div class="col-sm-3">
#    <strong>
#     Jaipur
#    </strong>
#    <br/>
#   </div>
#   <div class="col-sm-4">
#    127, Paras Hari Marg, Civil Lines,
#    <br/>
#    Jaipur, Rajasthan 302006
#    <br/>
#    India
#    <br/>
#    <strong>
#     Phone No:
#    </strong>
#    (+91)1412220832
#   </div>
#  </div>
#  <!-- end of content row -->
#  <div class="row">
#   <!-- description -->
#   <div class="col-sm-12">
#    <div class="wrap">
#     <a class="readmorebtn" onclick="$(this).text($(this).text() == '+more' ? '-less' : '+more').next('#listing_description_1031').slideToggle('fast');">
#      +more
#     </a>
#     <div id="listing_description_1031" style="display:none">
#      Vegetable Oil Machinery, Vanaspati Plant, Soap Plant, Herbal Extraction, Fractionation of Fatty Acids, Steam Generation Boiler, Thermic Fluid Heaters, Effluent Treatment Plants Soaps &amp; Detergent Plants
#     </div>
#    </div>
#    <!-- end of wrap -->
#   </div>
#   <!-- end of col-sm-12 -->
#  </div>
#  <!-- end of description -->
#  <!-- end of advertisement -->
# </div>
#
#
#
# -------
# 23
#
# <div class="col-sm-12">
#  <div class="row">
#   <!-- content row -->
#   <div class="col-sm-2">
#    <img alt="R.S. INDUSTRIES ROLLING MILLS LTD." class="img-responsive thumbnail view-img" src="http://www.indiabusinesstoday.in/assets/images/logo/no-logo.png" title="R.S. INDUSTRIES ROLLING MILLS LTD."/>
#    <div class="row">
#     <div class="col-sm-12">
#      <div class="stars" id="listing_rating">
#       <div class="controls">
#        <input class="rating" data-disabled="true" data-show-caption="false" data-show-clear="false" data-size="xs" id="input-ratings" max="5" min="0" step="0.5" type="number" value="2"/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="col-sm-3">
#    <div class="row col-sm-12">
#     <a href="http://www.indiabusinesstoday.in/detail/rs-industries-rolling-mills-ltd-1124">
#      R.S. INDUSTRIES ROLLING MILLS LTD.
#     </a>
#    </div>
#    <div class="row col-sm-12">
#     <button class="query btn btn-sm btn-primary" data-target="#query-modal" data-toggle="modal" id="1124" onclick="viewPage(1124);" type="button">
#      Send Query
#     </button>
#    </div>
#    <!-- end of ask query -->
#   </div>
#   <div class="col-sm-3">
#    <strong>
#     Jaipur
#    </strong>
#    <br/>
#   </div>
#   <div class="col-sm-4">
#    206, NAVJEEVAN COMPLEX,  29, STATION ROAD,
#    <br/>
#    Jaipur, Rajasthan 302006
#    <br/>
#    India
#    <br/>
#    <strong>
#     Phone No:
#    </strong>
#    (+91)1412366500/01/0
#   </div>
#  </div>
#  <!-- end of content row -->
#  <div class="row">
#   <!-- description -->
#   <div class="col-sm-12">
#    <div class="wrap">
#     <a class="readmorebtn" onclick="$(this).text($(this).text() == '+more' ? '-less' : '+more').next('#listing_description_1124').slideToggle('fast');">
#      +more
#     </a>
#     <div id="listing_description_1124" style="display:none">
#      ROLLING MILL EQUIPMENTS, STEEL ROADS, SHEET ROLLING MILL EQUIPMENTS, STEEL ROADS, SHEET Steel Rolling Mills Machinery
#     </div>
#    </div>
#    <!-- end of wrap -->
#   </div>
#   <!-- end of col-sm-12 -->
#  </div>
#  <!-- end of description -->
#  <!-- end of advertisement -->
# </div>
#
#
#
# -------
# 28
#
# <div class="col-sm-12">
#  <div class="row">
#   <!-- content row -->
#   <div class="col-sm-2">
#    <img alt="ADICHAWAL ENGINEERING WORKS" class="img-responsive thumbnail view-img" src="http://www.indiabusinesstoday.in/assets/images/logo/no-logo.png" title="ADICHAWAL ENGINEERING WORKS"/>
#    <div class="row">
#     <div class="col-sm-12">
#      <div class="stars" id="listing_rating">
#       <div class="controls">
#        <input class="rating" data-disabled="true" data-show-caption="false" data-show-clear="false" data-size="xs" id="input-ratings" max="5" min="0" step="0.5" type="number" value="4"/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="col-sm-3">
#    <div class="row col-sm-12">
#     <a href="http://www.indiabusinesstoday.in/detail/adichawal-engineering-works-1280">
#      ADICHAWAL ENGINEERING WORKS
#     </a>
#    </div>
#    <div class="row col-sm-12">
#     <button class="query btn btn-sm btn-primary" data-target="#query-modal" data-toggle="modal" id="1280" onclick="viewPage(1280);" type="button">
#      Send Query
#     </button>
#    </div>
#    <!-- end of ask query -->
#   </div>
#   <div class="col-sm-3">
#    <strong>
#     Jaipur
#    </strong>
#    <br/>
#   </div>
#   <div class="col-sm-4">
#    107, Shiv Vihar, Opposite Road no 5, VKI Area,
#    <br/>
#    Jaipur, Rajasthan 302013
#    <br/>
#    India
#    <br/>
#    <strong>
#     Phone No:
#    </strong>
#    (+91)1412330851
#   </div>
#  </div>
#  <!-- end of content row -->
#  <div class="row">
#   <!-- description -->
#   <div class="col-sm-12">
#    <div class="wrap">
#     <a class="readmorebtn" onclick="$(this).text($(this).text() == '+more' ? '-less' : '+more').next('#listing_description_1280').slideToggle('fast');">
#      +more
#     </a>
#     <div id="listing_description_1280" style="display:none">
#      High Quality Woolen Felt machines, Felt Milling M/c, Felt Hardner m/c, Felt Carding M/c., Non Woven machines-Needle Punch m/c etc.. High Quality Woolen Felt machines, Felt Milling M/c, Felt Hardner m/c, Felt Carding M/c., Non Woven machines-Needle Punch m
#     </div>
#    </div>
#    <!-- end of wrap -->
#   </div>
#   <!-- end of col-sm-12 -->
#  </div>
#  <!-- end of description -->
#  <!-- end of advertisement -->
# </div>
#
#
#
# -------
# 33
#
# <div class="col-sm-12">
#  <div class="row">
#   <!-- content row -->
#   <div class="col-sm-2">
#    <img alt="WEAVE N PRINTS" class="img-responsive thumbnail view-img" src="http://www.indiabusinesstoday.in/assets/images/logo/no-logo.png" title="WEAVE N PRINTS"/>
#    <div class="row">
#     <div class="col-sm-12">
#      <div class="stars" id="listing_rating">
#       <div class="controls">
#        <input class="rating" data-disabled="true" data-show-caption="false" data-show-clear="false" data-size="xs" id="input-ratings" max="5" min="0" step="0.5" type="number" value="4"/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="col-sm-3">
#    <div class="row col-sm-12">
#     <a href="http://www.indiabusinesstoday.in/detail/weave-n-prints-1281">
#      WEAVE N PRINTS
#     </a>
#    </div>
#    <div class="row col-sm-12">
#     <button class="query btn btn-sm btn-primary" data-target="#query-modal" data-toggle="modal" id="1281" onclick="viewPage(1281);" type="button">
#      Send Query
#     </button>
#    </div>
#    <!-- end of ask query -->
#   </div>
#   <div class="col-sm-3">
#    <strong>
#     Jaipur
#    </strong>
#    <br/>
#   </div>
#   <div class="col-sm-4">
#    Radha ballabh marg NEAR SILI-BERI, SANGANER,
#    <br/>
#    Jaipur, Rajasthan 303902
#    <br/>
#    India
#    <br/>
#    <strong>
#     Phone No:
#    </strong>
#    (+91)1412731106/3105
#   </div>
#  </div>
#  <!-- end of content row -->
#  <div class="row">
#   <!-- description -->
#   <div class="col-sm-12">
#    <div class="wrap">
#     <a class="readmorebtn" onclick="$(this).text($(this).text() == '+more' ? '-less' : '+more').next('#listing_description_1281').slideToggle('fast');">
#      +more
#     </a>
#     <div id="listing_description_1281" style="display:none">
#      TEXTILE PRINTER TEXTILE PRINTER Textile/Garment Machinery
#     </div>
#    </div>
#    <!-- end of wrap -->
#   </div>
#   <!-- end of col-sm-12 -->
#  </div>
#  <!-- end of description -->
#  <!-- end of advertisement -->
# </div>
#
#
#
# -------
# 38
#
# <div class="col-sm-12">
#  <div class="row">
#   <!-- content row -->
#   <div class="col-sm-2">
#    <img alt="J. J. EXPORT HOUSE" class="img-responsive thumbnail view-img" src="http://www.indiabusinesstoday.in/assets/images/logo/no-logo.png" title="J. J. EXPORT HOUSE"/>
#    <div class="row">
#     <div class="col-sm-12">
#      <div class="stars" id="listing_rating">
#       <div class="controls">
#        <input class="rating" data-disabled="true" data-show-caption="false" data-show-clear="false" data-size="xs" id="input-ratings" max="5" min="0" step="0.5" type="number" value="4.4"/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="col-sm-3">
#    <div class="row col-sm-12">
#     <a href="http://www.indiabusinesstoday.in/detail/j-j-export-house-1282">
#      J. J. EXPORT HOUSE
#     </a>
#    </div>
#    <div class="row col-sm-12">
#     <button class="query btn btn-sm btn-primary" data-target="#query-modal" data-toggle="modal" id="1282" onclick="viewPage(1282);" type="button">
#      Send Query
#     </button>
#    </div>
#    <!-- end of ask query -->
#   </div>
#   <div class="col-sm-3">
#    <strong>
#     Jaipur
#    </strong>
#    <br/>
#   </div>
#   <div class="col-sm-4">
#    B-9, Shivaji Godara Colony, Khatipura Road, Jhotwara,
#    <br/>
#    Jaipur, Rajasthan 302012
#    <br/>
#    India
#    <br/>
#    <strong>
#     Phone No:
#    </strong>
#    (+91)1412741773
#   </div>
#  </div>
#  <!-- end of content row -->
#  <div class="row">
#   <!-- description -->
#   <div class="col-sm-12">
#    <div class="wrap">
#     <a class="readmorebtn" onclick="$(this).text($(this).text() == '+more' ? '-less' : '+more').next('#listing_description_1282').slideToggle('fast');">
#      +more
#     </a>
#     <div id="listing_description_1282" style="display:none">
#      ALL KINDS INDUSTRIAL SEWING MACHINES, NEW &amp; USED SEWING MACHINES, KNITTING MACHINES, EMBROIDERY MACHINES Textile/Garment Machinery
#     </div>
#    </div>
#    <!-- end of wrap -->
#   </div>
#   <!-- end of col-sm-12 -->
#  </div>
#  <!-- end of description -->
#  <!-- end of advertisement -->
# </div>
#
#
#
# -------
# 43
#
# <div class="col-sm-12">
#  <div class="row">
#   <!-- content row -->
#   <div class="col-sm-2">
#    <img alt="ROYAL INDIA" class="img-responsive thumbnail view-img" src="http://www.indiabusinesstoday.in/assets/images/logo/no-logo.png" title="ROYAL INDIA"/>
#    <div class="row">
#     <div class="col-sm-12">
#      <div class="stars" id="listing_rating">
#       <div class="controls">
#        <input class="rating" data-disabled="true" data-show-caption="false" data-show-clear="false" data-size="xs" id="input-ratings" max="5" min="0" step="0.5" type="number" value="3.4"/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="col-sm-3">
#    <div class="row col-sm-12">
#     <a href="http://www.indiabusinesstoday.in/detail/royal-india-1518">
#      ROYAL INDIA
#     </a>
#    </div>
#    <div class="row col-sm-12">
#     <button class="query btn btn-sm btn-primary" data-target="#query-modal" data-toggle="modal" id="1518" onclick="viewPage(1518);" type="button">
#      Send Query
#     </button>
#    </div>
#    <!-- end of ask query -->
#   </div>
#   <div class="col-sm-3">
#    <strong>
#     Jaipur
#    </strong>
#    <br/>
#   </div>
#   <div class="col-sm-4">
#    b-9, shivaji godara colony, jhotwara,
#    <br/>
#    Jaipur, Rajasthan 302012
#    <br/>
#    India
#    <br/>
#    <strong>
#     Phone No:
#    </strong>
#    (+91)1412340240
#   </div>
#  </div>
#  <!-- end of content row -->
#  <div class="row">
#   <!-- description -->
#   <div class="col-sm-12">
#    <div class="wrap">
#     <a class="readmorebtn" onclick="$(this).text($(this).text() == '+more' ? '-less' : '+more').next('#listing_description_1518').slideToggle('fast');">
#      +more
#     </a>
#     <div id="listing_description_1518" style="display:none">
#      USED SEWING MACHINES Used Machinery
#     </div>
#    </div>
#    <!-- end of wrap -->
#   </div>
#   <!-- end of col-sm-12 -->
#  </div>
#  <!-- end of description -->
#  <!-- end of advertisement -->
# </div>
#
#
#
# -------
# 48
#
# <div class="col-sm-12">
#  <div class="row">
#   <!-- content row -->
#   <div class="col-sm-2">
#    <img alt="MAXCARE" class="img-responsive thumbnail view-img" src="http://www.indiabusinesstoday.in/assets/images/logo/no-logo.png" title="MAXCARE"/>
#    <div class="row">
#     <div class="col-sm-12">
#      <div class="stars" id="listing_rating">
#       <div class="controls">
#        <input class="rating" data-disabled="true" data-show-caption="false" data-show-clear="false" data-size="xs" id="input-ratings" max="5" min="0" step="0.5" type="number" value="4"/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="col-sm-3">
#    <div class="row col-sm-12">
#     <a href="http://www.indiabusinesstoday.in/detail/maxcare-1558">
#      MAXCARE
#     </a>
#    </div>
#    <div class="row col-sm-12">
#     <button class="query btn btn-sm btn-primary" data-target="#query-modal" data-toggle="modal" id="1558" onclick="viewPage(1558);" type="button">
#      Send Query
#     </button>
#    </div>
#    <!-- end of ask query -->
#   </div>
#   <div class="col-sm-3">
#    <strong>
#     Jaipur
#    </strong>
#    <br/>
#   </div>
#   <div class="col-sm-4">
#    15, AGRASEN TOWER, CENTRAL SPINE, VIDHYADHAR NAGAR,
#    <br/>
#    Jaipur, Rajasthan 302023
#    <br/>
#    India
#    <br/>
#    <strong>
#     Phone No:
#    </strong>
#    (+91)1416450929/3229
#   </div>
#  </div>
#  <!-- end of content row -->
#  <div class="row">
#   <!-- description -->
#   <div class="col-sm-12">
#    <div class="wrap">
#     <a class="readmorebtn" onclick="$(this).text($(this).text() == '+more' ? '-less' : '+more').next('#listing_description_1558').slideToggle('fast');">
#      +more
#     </a>
#     <div id="listing_description_1558" style="display:none">
#      R.O. WATER PURIFIER R.O. WATER PURIFIER Water Softener &amp; Purifier
#     </div>
#    </div>
#    <!-- end of wrap -->
#   </div>
#   <!-- end of col-sm-12 -->
#  </div>
#  <!-- end of description -->
#  <!-- end of advertisement -->
# </div>
#
#
#
# -------
# 53
#
# <div class="col-sm-12">
#  <div class="row">
#   <!-- content row -->
#   <div class="col-sm-2">
#    <img alt="AVEREADY SCALE INDIA" class="img-responsive thumbnail view-img" src="http://www.indiabusinesstoday.in/assets/images/logo/no-logo.png" title="AVEREADY SCALE INDIA"/>
#    <div class="row">
#     <div class="col-sm-12">
#      <div class="stars" id="listing_rating">
#       <div class="controls">
#        <input class="rating" data-disabled="true" data-show-caption="false" data-show-clear="false" data-size="xs" id="input-ratings" max="5" min="0" step="0.5" type="number" value="1.8"/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="col-sm-3">
#    <div class="row col-sm-12">
#     <a href="http://www.indiabusinesstoday.in/detail/aveready-scale-india-1567">
#      AVEREADY SCALE INDIA
#     </a>
#    </div>
#    <div class="row col-sm-12">
#     <button class="query btn btn-sm btn-primary" data-target="#query-modal" data-toggle="modal" id="1567" onclick="viewPage(1567);" type="button">
#      Send Query
#     </button>
#    </div>
#    <!-- end of ask query -->
#   </div>
#   <div class="col-sm-3">
#    <strong>
#     Jaipur
#    </strong>
#    <br/>
#   </div>
#   <div class="col-sm-4">
#    F-48, Vaishali Nagar,
#    <br/>
#    Jaipur, Rajasthan 302021
#    <br/>
#    India
#    <br/>
#    <strong>
#     Phone No:
#    </strong>
#    (+91)1412353064
#   </div>
#  </div>
#  <!-- end of content row -->
#  <div class="row">
#   <!-- description -->
#   <div class="col-sm-12">
#    <div class="wrap">
#     <a class="readmorebtn" onclick="$(this).text($(this).text() == '+more' ? '-less' : '+more').next('#listing_description_1567').slideToggle('fast');">
#      +more
#     </a>
#     <div id="listing_description_1567" style="display:none">
#      WEIGHING MACHINE &amp; WEIGH BRIDGE WEIGHING MACHINE &amp; WEIGH BRIDGE Weighing Machines
#     </div>
#    </div>
#    <!-- end of wrap -->
#   </div>
#   <!-- end of col-sm-12 -->
#  </div>
#  <!-- end of description -->
#  <!-- end of advertisement -->
# </div>

# %% [markdown]
# ### Company names in first page

# %%
for i in range(6,len(table)):
    if table[i].find('div',{'class':'row col-sm-12'}):
        print table[i].find('a').text
# Out:
# Shree Kamdhenu Electronics Pvt Ltd
# welding flux manufacturer from China -- Yulin Welding Material
# Shree Kamdhenu Electronics Pvt Ltd
# AGROCON INTERNATIONAL
# R.S. INDUSTRIES ROLLING MILLS LTD.
# ADICHAWAL ENGINEERING WORKS
# WEAVE N PRINTS
# J. J. EXPORT HOUSE
# ROYAL INDIA
# MAXCARE
# AVEREADY SCALE INDIA

# %% [markdown]
# ## Try for many pages

# %%
url='http://www.indiabusinesstoday.in/category/plant-and-machinery-1-834/'
page=range(10,21,10)
urllist=[url]
for item in page:
    urllist.append(url+str(item))

# %%
from time import sleep

# %%
for url in urllist:
    
    print "\nurl:"+url+"\n"
    response = requests.get(url)
    html = response.content
    soup = BeautifulSoup(html)
    table = soup.find_all('div', {'class':'col-sm-12'})
    for i in range(7,len(table)):
        if table[i].find('div',{'class':'row col-sm-12'}):
            print table[i].find('a').text
# Out:
# url:http://www.indiabusinesstoday.in/category/plant-and-machinery-1-834/
#
# RRR Bio Tec (M)
# Packone Solutions LLP
# Vortech Private Limited
# Toshniwal Instruments Pvt Ltd.
# JX Shot Blasting Machine Co., Ltd.
# 3Deometry Innovations
# Shruti Flexipack Pvt Ltd
# Shiva Kitchen Equipments Pvt. Ltd.
# Flu-tech
# Sifter International
#
# url:http://www.indiabusinesstoday.in/category/plant-and-machinery-1-834/10
#
# welding flux manufacturer from China -- Yulin Welding Material
# Shree Kamdhenu Electronics Pvt Ltd
# AGROCON INTERNATIONAL
# R.S. INDUSTRIES ROLLING MILLS LTD.
# ADICHAWAL ENGINEERING WORKS
# WEAVE N PRINTS
# J. J. EXPORT HOUSE
# ROYAL INDIA
# MAXCARE
# AVEREADY SCALE INDIA
#
# url:http://www.indiabusinesstoday.in/category/plant-and-machinery-1-834/20
#
# PUMA ELECTRO INDUSTRIES
# BHARAT ROLLING MILL
# UNIVERSAL GEAR INDUSTRIES & ENGINEERING WORKS
# AMAR IRON UDYOG PVT. LTD.
# S. M. S. I LTD.
# MULTI-SERVE ROLLS LIMITED
# GARG MACHINERY UDYOG PVT. LTD.
# GARDEN PRODUCTS
# GEM TEA MACHINERY PVT. LTD.
# GIMPEX OVERSEAS PVT. LTD.

# %% [markdown]
# ## Try other fields (one page)

# %%
url='http://www.indiabusinesstoday.in/category/plant-and-machinery-1-834/'
    
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
table = soup.find_all('div', {'class':'col-sm-12'})
phone=soup.find_all('strong')
for phone in phone:
    if phone.text=='Phone No: ':
        phone=phone.next_sibling
        print phone
for i in range(7,len(table)):
    if table[i].find('div',{'class':'row col-sm-12'}):
        print table[i].find('a').text
        sub_url=table[i].find('a')['href']
        sub_response = requests.get(sub_url)
        sub_html=sub_response.content
        sub_soup=BeautifulSoup(sub_html)
        street_address=sub_soup.find('span',{'itemprop':'streetAddress'})
        print street_address.text
        city=sub_soup.find('span',{'itemprop':'addressLocality'})
        print city.text
        pincode=city.next_sibling
        print pincode
        state=sub_soup.find('span',{'itemprop':'addressRegion'})
        print state.text
        person=sub_soup.find('span',{'class':'glyphicon-user'})
        person=person.find_next('span')
        print person.text.strip()
# Out:
# 02692-235390
# 8073911917, 8073911917
# 8268661832
# 8980109849, 02717661661
# +(91)-(44)-26441820
# +918444844368
# 9764751920, 9503817139
# 7506129084, +91 9619909581
# 9836677775, 91-33-2231-9182
# 09825318474, 07940084051
# +919910030832, +911294067129
# RRR Bio Tec (M)
# #3452/1b, Tilak Nagar
# Mysore.
# Mysuru
#  570021
# Karnataka
# D Kumar
# Packone Solutions LLP
# B3, Devashree Park, Opp. Sandoz Baug PO, Kolshet Rd
# Thane
#  400607
# Maharashtra
# Varun Fotedar
# Vortech Private Limited
# Survey No. 427 P/3-4, &amp;amp;amp;amp;amp;amp;amp;amp;amp; 431 P/1-2,
# Sarkhej-Bavla Highway, Moraiya,
# Tal Sanand, Dist. Ahmedabad
# Ahmedabad
#  382213
# Gujarat
# Pratik Panchal
# Toshniwal Instruments Pvt Ltd.
# Toshniwal Instruments (Madras) Pvt. Ltd, 267, Kilpauk   Garden Road Chennai
# http://www.toshniwal.net/
# Chennai
#  600 010
# Tamil Nadu
# Robin Joseph
# JX Shot Blasting Machine Co., Ltd.
# 83 A and B, Topsia Rd, Topsia
# Kolkata
#  700046
# West Bengal
# Jeasin Huang
# 3Deometry Innovations
# Office 208, Gran Exito, BT Kawade Road, Above Axis Bank, Ghorpodi
# Pune
#  411001
# Maharashtra
# Shaneel Karia
# Shruti Flexipack Pvt Ltd
# Plot No. B-49 MIDC Road Behind Reliable Plaza
# TTC Industrial Area Off. Thane - Belapur Road Airoli
#
#
# Navi Mumbai
#  400708
# Maharashtra
# Sharayu Sawant
# Shiva Kitchen Equipments Pvt. Ltd.
# 1, Waterloo Street
# Kolkata
#  700069
# West Bengal
# Manishaa Jaiswal
# Flu-tech
# Plot No.3212, BH: Benzo Products, Ph-IV, GIDC Estate, Vatva,
# Ahmedabad
#  382445
# Gujarat
# Mr. Ramesh Panchal
# Sifter International
# Plot Number 83, Sector 6, Industrial Area
# Faridabad
#  121006
# Haryana
# Mr S C Sharma

# %% [markdown]
# ## (many pages)

# %%
companies=[]
street_addresses=[]
cities=[]
states=[]
pincodes=[]
contact_persons=[]
phones=[]

# %%
# %%capture
url='http://www.indiabusinesstoday.in/category/plant-and-machinery-1-834/'

page=range(10,501,10)
urllist=[url]
for item in page:
    urllist.append(url+str(item))

for url in urllist:

    response = requests.get(url)
    html = response.content
    soup = BeautifulSoup(html)
    table = soup.find_all('div', {'class':'col-sm-12'})
    phone=soup.find_all('strong')
    for phone in phone:
        if phone.text=='Phone No: ':
            phone=phone.next_sibling
            phones.append(phone)
            
    for i in range(7,len(table)):
        if table[i].find('div',{'class':'row col-sm-12'}):
            print table[i].find('a').text
            companies.append(table[i].find('a').text)
            
            sub_url=table[i].find('a')['href']
            sub_response = requests.get(sub_url)
            sub_html=sub_response.content
            sub_soup=BeautifulSoup(sub_html)
            street_address=sub_soup.find('span',{'itemprop':'streetAddress'})
            street_addresses.append(street_address.text)
            
            city=sub_soup.find('span',{'itemprop':'addressLocality'})
            cities.append(city.text)
            
            pincode=city.next_sibling
            pincodes.append(pincode)
            
            state=sub_soup.find('span',{'itemprop':'addressRegion'})
            states.append(state.text)
            
            person=sub_soup.find('span',{'class':'glyphicon-user'})
            person=person.find_next('span')
            contact_persons.append(person.text.strip())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-11d919b1b906> in <module>()
#      40
#      41             person=sub_soup.find('span',{'class':'glyphicon-user'})
# ---> 42             person=person.find_next('span')
#      43             contact_persons.append(person.text.strip())
#
# AttributeError: 'NoneType' object has no attribute 'find_next'

# %%
import pandas as pd

# %%
companies_df=pd.DataFrame({'Company':companies,'Contact Name':contact_persons,
                               'Street Address':street_addresses,'City':cities,
                                'State':states,'Pincode':pincodes,'Contact No.':phones});

# %%
companies_df.head()
# Out:
#         City                             Company    Contact Name  \
# 0     Mysuru                     RRR Bio Tec (M)         D Kumar
# 1      Thane               Packone Solutions LLP   Varun Fotedar
# 2  Ahmedabad             Vortech Private Limited  Pratik Panchal
# 3    Chennai      Toshniwal Instruments Pvt Ltd.    Robin Joseph
# 4    Kolkata  JX Shot Blasting Machine Co., Ltd.    Jeasin Huang
#
#                   Contact No.   Pincode        State  \
# 0             02692-235390			    570021    Karnataka
# 1   8073911917, 8073911917			    400607  Maharashtra
# 2               8268661832			    382213      Gujarat
# 3  8980109849, 02717661661			   600 010   Tamil Nadu
# 4      +(91)-(44)-26441820			    700046  West Bengal
#
#                                       Street Address
# 0                     #3452/1b, Tilak Nagar\nMysore.
# 1  B3, Devashree Park, Opp. Sandoz Baug PO, Kolsh...
# 2  Survey No. 427 P/3-4, &amp;amp;amp;amp;amp;amp...
# 3  Toshniwal Instruments (Madras) Pvt. Ltd, 267, ...
# 4                      83 A and B, Topsia Rd, Topsia

# %%
companies_df.to_csv('scraped_data.csv')
